# %% [markdown]
# ### Step to step details
#
# 1. Created a new environment (Cardekho_python= 3.10)
# 2. Working directory (Launched jupyter notebook)

# %%
 # import libraries 
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('car data.csv') # loading the dataset
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
# find the unique value of categorical features
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
# read each iteration by using for loop
for i in df.columns:
    print(df[i].unique())
# Out:
# ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer '
#  'Honda Activa 4G' 'TVS Sport ' 'Honda Dream Yuga '
# ...

# %%
df['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
# check the null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# exploratory data analysis
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# We can remove the car name or drop the car name as it is not requirement
final_dataset = df.drop(['Car_Name'],axis = 1)

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
final_dataset['Current_year'] =2024

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_year
# 0         Manual      0          2024
# ...

# %%
# calcualte the how many year old of a car
final_dataset['Numnber_year'] = final_dataset['Current_year']-final_dataset['Year']

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_year  Numnber_year
# ...

# %%
final_dataset.drop(['Year','Current_year'],axis=1, inplace=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Numnber_year
# 0       Manual      0            10
# 1       Manual      0            11
# 2       Manual      0             7
# 3       Manual      0            13
# 4       Manual      0            10

# %%
final_dataset['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Numnber_year
# 0         Manual      0            10
# 1         Manual      0            11
# ...

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Selling_Price  301 non-null    float64
#  1   Present_Price  301 non-null    float64
#  2   Kms_Driven     301 non-null    int64
#  3   Fuel_Type      301 non-null    object
#  4   Seller_Type    301 non-null    object
#  5   Transmission   301 non-null    object
#  6   Owner          301 non-null    int64
#  7   Numnber_year   301 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 18.9+ KB

# %%
import seaborn as sns
sns.countplot(final_dataset,x=final_dataset['Numnber_year'],hue=final_dataset['Fuel_Type'])
# Out:
# <Axes: xlabel='Numnber_year', ylabel='count'>

# %%
final_dataset= pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Numnber_year  \
# 0             3.35           5.59       27000      0            10
# 1             4.75           9.54       43000      0            11
# 2             7.25           9.85        6900      0             7
# 3             2.85           4.15        5200      0            13
# 4             4.60           6.87       42450      0            10
# ..             ...            ...         ...    ...           ...
# 296           9.50          11.60       33988      0             8
# 297           4.00           5.90       60000      0             9
# 298           3.35          11.00       87934      0            15
# 299          11.50          12.50        9000      0             7
# 300           5.30           5.90        5464      0             8
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# ...

# %%
final_dataset['Fuel_Type_Petrol']= final_dataset['Fuel_Type_Petrol'].astype(int)
final_dataset['Seller_Type_Individual']= final_dataset['Seller_Type_Individual'].astype(int)
final_dataset['Transmission_Manual']= final_dataset['Transmission_Manual'].astype(int)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Numnber_year  \
# 0             3.35           5.59       27000      0            10
# 1             4.75           9.54       43000      0            11
# 2             7.25           9.85        6900      0             7
# 3             2.85           4.15        5200      0            13
# 4             4.60           6.87       42450      0            10
# ..             ...            ...         ...    ...           ...
# 296           9.50          11.60       33988      0             8
# 297           4.00           5.90       60000      0             9
# 298           3.35          11.00       87934      0            15
# 299          11.50          12.50        9000      0             7
# 300           5.30           5.90        5464      0             8
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False                 1                       0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Display the correlation between the features
corr_matrix = final_dataset.corr()
top_corr = corr_matrix.index
plt.figure(figsize=(20,20))
sns.heatmap(final_dataset[top_corr].corr(),annot=True,cmap='RdYlGn')
# Out:
# <Axes: >

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Numnber_year  \
# 0             3.35           5.59       27000      0            10
# 1             4.75           9.54       43000      0            11
# 2             7.25           9.85        6900      0             7
# 3             2.85           4.15        5200      0            13
# 4             4.60           6.87       42450      0            10
# ..             ...            ...         ...    ...           ...
# 296           9.50          11.60       33988      0             8
# 297           4.00           5.90       60000      0             9
# 298           3.35          11.00       87934      0            15
# 299          11.50          12.50        9000      0             7
# 300           5.30           5.90        5464      0             8
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False                 1                       0
# ...

# %%
# Split the independent and dependent variables
X = final_dataset.iloc[:,1:]

# %%
y =final_dataset.iloc[:,0]

# %% [markdown]
# The key distinction between Classification vs Regression algorithms is Regression algorithms are used to determine continuous values such as price, income, age, etc. and Classification algorithms are used to forecast or classify the distinct values such as Real or False, Male or Female, Spam or Not Spam, etc.

# %%
# Feature Importance 
from sklearn.ensemble import ExtraTreesRegressor

# %%
# find the top 5 fiture from final dataset
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.35837571 0.03937431 0.00081229 0.07950063 0.23581863 0.00599493
#  0.13362883 0.14649466]

# %%
# Plot graph of feature importances for better visualizations

feature_imp = pd.Series(model.feature_importances_, index=X.columns) # Should be converted into Series
feature_imp.nlargest(5).plot(kind='barh') # find the top 5 important features 
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.shape
X_test.shape
# Out:
# (61, 8)

# %% [markdown]
# ### Random Forest
#
# Random Forest is a classifier that contains a number of decision trees on various subsets of the given dataset and takes the average to improve the predictive accuracy of that dataset.

# %%
from sklearn.ensemble import RandomForestRegressor
randor_r = RandomForestRegressor()#n_estimators are decision Trees

# %%
randor_r.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict = randor_r.predict(X_test)
y_predict
# Out:
# array([ 4.02  ,  0.4637,  4.731 ,  5.5765,  1.071 ,  5.7345,  3.454 ,
#         5.1918,  0.3264,  3.3875,  7.0885,  5.8276,  7.2473,  2.8085,
#         3.362 ,  3.0665,  5.2035,  7.1648,  0.2208,  5.1918, 10.3639,
#         2.7005,  3.258 ,  4.4005,  8.2069,  0.2294,  7.6584,  0.6627,
#        17.7837,  6.0483,  1.0372,  5.6705,  8.3139, 20.3396,  8.7077,
#         6.7992, 17.8096,  6.6141,  0.227 ,  1.555 ,  0.428 ,  5.3605,
#         2.8805,  8.5959,  3.2264,  0.4892,  1.0205,  1.15  ,  0.6093,
#         5.367 ,  1.084 ,  0.2794,  2.584 ,  0.539 ,  0.35  ,  0.5561,
#         5.0695,  2.8545,  4.1075,  0.4323,  1.9105])

# %%
sns.distplot(y_test-y_predict)
# Out:
# C:\Users\avinash.archanapelli\AppData\Local\Temp\ipykernel_19392\2207969917.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_predict)
# D:\DOUBT SHEET\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(y_test,y_predict)

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
# After training the model
with open('random_forest_regression_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
try:
    with open('random_forest_regression_model.pkl', 'rb') as file:
        model = pickle.load(file)
except Exception as e:
    print(f"Error loading the model: {e}")

# %%
import os
os.getcwd()
# Out:
# 'D:\\Impemention end to end\\Krishnaik end to end projects'
